# %% [markdown]
# # 수업시간 및 수강신청 안내

# %% [markdown]
# ## 8. 수업시간 안내
# ### 안양캠퍼스 (주간)
# - 1교시: 09:00 ~ 09:50 | 9교시: 17:00 ~ 17:50
# - 2교시: 10:00 ~ 10:50 | 10교시: 17:55 ~ 18:45
# - 3교시: 11:00 ~ 11:50 | 11교시: 18:50 ~ 19:40
# - 4교시: 12:00 ~ 12:50 | 12교시: 19:45 ~ 20:35
# - 5교시: 13:00 ~ 13:50 | 13교시: 20:40 ~ 21:30
# - 6교시: 14:00 ~ 14:50 | 14교시: 21:35 ~ 22:25
# - 7교시: 15:00 ~ 15:50
# - 8교시: 16:00 ~ 16:50
#
# ### 강화캠퍼스 (주간)
# - 1교시: 10:00 ~ 10:50 | 5교시: 14:30 ~ 15:20
# - 2교시: 11:00 ~ 11:50 | 6교시: 15:30 ~ 16:20
# - 점심시간: 12:50 ~ 13:30 | 7교시: 16:30 ~ 17:20
# - 3교시: 12:00 ~ 12:50 | 8교시: 17:30 ~ 18:20
# - 4교시: 13:30 ~ 14:20

# %% [markdown]
# ## 9. 수강신청 문의
# ### 안양캠퍼스 교양
# - 전화번호: 031-463-1362, 1384
#
# ### 강화캠퍼스 교양
# - 전화번호: 032-930-6210

# %% [markdown]
# ### 학과별 문의
# - **신학대학**: 467-0942
# - **국어국문학과**: 467-0785
# - **중국어문화학과**: 467-0786
# - **영어문화학과**: 467-0762
# - **유아교육과**: 463-1364
# - **러시아언어문화학과**: 467-0787

# %% [markdown]
# ### 사회과학대학
# - 글로벌경영학과: 467-0935 / 0911
# - 관광경영학과: 463-1344
# - 행정학과: 467-0937
# - 공공정책학과(강화): 032-930-6281
# - 관광학과(강화): 032-930-6283

# %% [markdown]
# ### 예술대학
# - 공예예술학과: 467-0915
# - 음악학과: 463-1357
# - 화장품발명디자인학과: 463-1230
# - 뷰티디자인학과: 463-1323

# %% [markdown]
# ### 스포츠대학
# - 스포츠과학과(강화): 032-930-6289
# - 체육학과(강화): 032-930-6289
# - 스포츠산업학과(강화): 032-930-6290

# %% [markdown]
# ### 창의융합대학
# - 컴퓨터공학과: 463-1347
# - 통계데이터사이언스학과: 463-1348
# - 정보전자기공학과: 463-1313
# - 소프트웨어학과: 463-1363
# - 도시정보공학과: 463-1349
